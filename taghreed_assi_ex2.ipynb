# %%
#https://github.com/TaghreedAssi/machinelearning-link to github
# %load_ext tensorboard
import datetime, os
import tensorflow as tf
import tensorflow_datasets as tfds
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %% [markdown]
# Load the DB

# %%
(ds_train, ds_test), ds_info = tfds.load(
    'mnist',
    split=['train', 'test'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True,
)

num_of_classes = ds_info.features['label'].num_classes
image_shape = ds_info.features['image'].shape
train_size = ds_info.splits['train'].num_examples
test_size = ds_info.splits['test'].num_examples


print(num_of_classes)
print(image_shape)
print(train_size)
print(test_size)
# Out:
# 10
# (28, 28, 1)
# 60000
# 10000

# %% [markdown]
# Data preprocessing

# %%
def normalize_img(image, label):
  """Normalizes images: `uint8` -> `float32`."""
  return tf.cast(image, tf.float32) / 255., label

ds_train = ds_train.map(
    normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
ds_train = ds_train.cache()
ds_train = ds_train.shuffle(ds_info.splits['train'].num_examples)
ds_train = ds_train.batch(32)
ds_train = ds_train.prefetch(tf.data.AUTOTUNE)


ds_test = ds_test.map(
    normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
ds_test = ds_test.batch(128)
ds_test = ds_test.cache()
ds_test = ds_test.prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# 6. Deeper network relu + regularization + batchnormalization

# %%
layers = [
  tf.keras.layers.Flatten(input_shape=image_shape),
  tf.keras.layers.Dense(95, kernel_regularizer=tf.keras.regularizers.l2(0.0001)),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Activation('elu'),
  tf.keras.layers.Dropout(0.1),

  tf.keras.layers.Dense(28, kernel_regularizer=tf.keras.regularizers.l2(0.001)),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Activation('elu'),
  tf.keras.layers.Dropout(0.1),

  tf.keras.layers.Dense(23, kernel_regularizer=tf.keras.regularizers.l2(0.01)),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Activation('elu'),
  tf.keras.layers.Dropout(0.1),

   tf.keras.layers.Dense(13, kernel_regularizer=tf.keras.regularizers.l2(0.1)),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Activation('elu'),
  tf.keras.layers.Dropout(0.1),

  tf.keras.layers.Dense(num_of_classes),
  tf.keras.layers.Softmax()
  ]
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# Define sequential model

# %%
model = tf.keras.models.Sequential(layers)

model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_7 (Flatten)                  │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_35 (Dense)                     │ (None, 95)                  │          74,575 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_28               │ (None, 95)                  │             380 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_28 (Activation)           │ (None, 95)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_23 (Dropout)                 │ (None, 95)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_36 (Dense)                     │ (None, 28)                  │           2,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_29               │ (None, 28)                  │             112 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_29 (Activation)           │ (None, 28)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_24 (Dropout)                 │ (None, 28)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_37 (Dense)                     │ (None, 23)                  │             667 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_30               │ (None, 23)                  │              92 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_30 (Activation)           │ (None, 23)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_25 (Dropout)                 │ (None, 23)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_38 (Dense)                     │ (None, 13)                  │             312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_31               │ (None, 13)                  │              52 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_31 (Activation)           │ (None, 13)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_26 (Dropout)                 │ (None, 13)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_39 (Dense)                     │ (None, 10)                  │             140 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ softmax_7 (Softmax)                  │ (None, 10)                  │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 79,018 (308.66 KB)
#  Trainable params: 78,700 (307.42 KB)
#  Non-trainable params: 318 (1.24 KB)

# %% [markdown]
# Train the model

# %%
model.fit(ds_train,
          epochs=50,
          validation_data=ds_test)
# Out:
# Epoch 1/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - loss: 3.3584 - sparse_categorical_accuracy: 0.7589 - val_loss: 0.7162 - val_sparse_categorical_accuracy: 0.9115
# Epoch 2/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.8207 - sparse_categorical_accuracy: 0.8746 - val_loss: 0.6066 - val_sparse_categorical_accuracy: 0.9268
# Epoch 3/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.7297 - sparse_categorical_accuracy: 0.8893 - val_loss: 0.5151 - val_sparse_categorical_accuracy: 0.9460
# Epoch 4/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.6841 - sparse_categorical_accuracy: 0.9008 - val_loss: 0.5399 - val_sparse_categorical_accuracy: 0.9381
# Epoch 5/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.6557 - sparse_categorical_accuracy: 0.9059 - val_loss: 0.4917 - val_sparse_categorical_accuracy: 0.9511
# Epoch 6/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.6437 - sparse_categorical_accuracy: 0.9072 - val_loss: 0.4868 - val_sparse_categorical_accuracy: 0.9505
# Epoch 7/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.6143 - sparse_categorical_accuracy: 0.9147 - val_loss: 0.4967 - val_sparse_categorical_accuracy: 0.9497
# Epoch 8/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.6027 - sparse_categorical_accuracy: 0.9151 - val_loss: 0.4664 - val_sparse_categorical_accuracy: 0.9576
# Epoch 9/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.5956 - sparse_categorical_accuracy: 0.9184 - val_loss: 0.4681 - val_sparse_categorical_accuracy: 0.9555
# Epoch 10/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.5925 - sparse_categorical_accuracy: 0.9178 - val_loss: 0.4533 - val_sparse_categorical_accuracy: 0.9578
# Epoch 11/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.5857 - sparse_categorical_accuracy: 0.9187 - val_loss: 0.4535 - val_sparse_categorical_accuracy: 0.9578
# Epoch 12/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.5768 - sparse_categorical_accuracy: 0.9221 - val_loss: 0.4310 - val_sparse_categorical_accuracy: 0.9621
# Epoch 13/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.5709 - sparse_categorical_accuracy: 0.9222 - val_loss: 0.4464 - val_sparse_categorical_accuracy: 0.9581
# Epoch 14/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.5595 - sparse_categorical_accuracy: 0.9252 - val_loss: 0.4167 - val_sparse_categorical_accuracy: 0.9658
# Epoch 15/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.5598 - sparse_categorical_accuracy: 0.9258 - val_loss: 0.4237 - val_sparse_categorical_accuracy: 0.9637
# Epoch 16/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.5632 - sparse_categorical_accuracy: 0.9240 - val_loss: 0.4233 - val_sparse_categorical_accuracy: 0.9621
# Epoch 17/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.5613 - sparse_categorical_accuracy: 0.9246 - val_loss: 0.4245 - val_sparse_categorical_accuracy: 0.9614
# Epoch 18/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.5466 - sparse_categorical_accuracy: 0.9273 - val_loss: 0.4431 - val_sparse_categorical_accuracy: 0.9576
# Epoch 19/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.5516 - sparse_categorical_accuracy: 0.9251 - val_loss: 0.3914 - val_sparse_categorical_accuracy: 0.9692
# Epoch 20/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.5441 - sparse_categorical_accuracy: 0.9260 - val_loss: 0.4175 - val_sparse_categorical_accuracy: 0.9636
# Epoch 21/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.5437 - sparse_categorical_accuracy: 0.9265 - val_loss: 0.4274 - val_sparse_categorical_accuracy: 0.9617
# Epoch 22/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.5389 - sparse_categorical_accuracy: 0.9275 - val_loss: 0.4262 - val_sparse_categorical_accuracy: 0.9593
# Epoch 23/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.5344 - sparse_categorical_accuracy: 0.9287 - val_loss: 0.4006 - val_sparse_categorical_accuracy: 0.9659
# Epoch 24/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.5323 - sparse_categorical_accuracy: 0.9297 - val_loss: 0.4110 - val_sparse_categorical_accuracy: 0.9631
# Epoch 25/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.5431 - sparse_categorical_accuracy: 0.9256 - val_loss: 0.4214 - val_sparse_categorical_accuracy: 0.9623
# Epoch 26/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.5261 - sparse_categorical_accuracy: 0.9297 - val_loss: 0.3998 - val_sparse_categorical_accuracy: 0.9676
# Epoch 27/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.5357 - sparse_categorical_accuracy: 0.9284 - val_loss: 0.4194 - val_sparse_categorical_accuracy: 0.9593
# Epoch 28/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.5352 - sparse_categorical_accuracy: 0.9264 - val_loss: 0.4016 - val_sparse_categorical_accuracy: 0.9655
# Epoch 29/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.5276 - sparse_categorical_accuracy: 0.9299 - val_loss: 0.3917 - val_sparse_categorical_accuracy: 0.9683
# Epoch 30/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.5223 - sparse_categorical_accuracy: 0.9304 - val_loss: 0.4067 - val_sparse_categorical_accuracy: 0.9630
# Epoch 31/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.5275 - sparse_categorical_accuracy: 0.9283 - val_loss: 0.4193 - val_sparse_categorical_accuracy: 0.9598
# Epoch 32/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.5209 - sparse_categorical_accuracy: 0.9304 - val_loss: 0.4284 - val_sparse_categorical_accuracy: 0.9589
# Epoch 33/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.5254 - sparse_categorical_accuracy: 0.9307 - val_loss: 0.3959 - val_sparse_categorical_accuracy: 0.9643
# Epoch 34/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.5214 - sparse_categorical_accuracy: 0.9307 - val_loss: 0.3823 - val_sparse_categorical_accuracy: 0.9714
# Epoch 35/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.5259 - sparse_categorical_accuracy: 0.9297 - val_loss: 0.4012 - val_sparse_categorical_accuracy: 0.9663
# Epoch 36/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.5270 - sparse_categorical_accuracy: 0.9286 - val_loss: 0.4063 - val_sparse_categorical_accuracy: 0.9657
# Epoch 37/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.5245 - sparse_categorical_accuracy: 0.9300 - val_loss: 0.3967 - val_sparse_categorical_accuracy: 0.9659
# Epoch 38/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.5233 - sparse_categorical_accuracy: 0.9303 - val_loss: 0.4522 - val_sparse_categorical_accuracy: 0.9511
# Epoch 39/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.5234 - sparse_categorical_accuracy: 0.9299 - val_loss: 0.3886 - val_sparse_categorical_accuracy: 0.9679
# Epoch 40/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.5219 - sparse_categorical_accuracy: 0.9300 - val_loss: 0.4030 - val_sparse_categorical_accuracy: 0.9634
# Epoch 41/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.5196 - sparse_categorical_accuracy: 0.9316 - val_loss: 0.4008 - val_sparse_categorical_accuracy: 0.9650
# Epoch 42/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.5192 - sparse_categorical_accuracy: 0.9319 - val_loss: 0.3926 - val_sparse_categorical_accuracy: 0.9663
# Epoch 43/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.5282 - sparse_categorical_accuracy: 0.9293 - val_loss: 0.3949 - val_sparse_categorical_accuracy: 0.9691
# Epoch 44/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.5241 - sparse_categorical_accuracy: 0.9293 - val_loss: 0.3961 - val_sparse_categorical_accuracy: 0.9651
# Epoch 45/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.5218 - sparse_categorical_accuracy: 0.9314 - val_loss: 0.4010 - val_sparse_categorical_accuracy: 0.9647
# Epoch 46/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.5200 - sparse_categorical_accuracy: 0.9317 - val_loss: 0.4093 - val_sparse_categorical_accuracy: 0.9609
# Epoch 47/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.5286 - sparse_categorical_accuracy: 0.9289 - val_loss: 0.3875 - val_sparse_categorical_accuracy: 0.9667
# Epoch 48/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.5250 - sparse_categorical_accuracy: 0.9292 - val_loss: 0.3946 - val_sparse_categorical_accuracy: 0.9690
# Epoch 49/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.5204 - sparse_categorical_accuracy: 0.9309 - val_loss: 0.3771 - val_sparse_categorical_accuracy: 0.9696
# Epoch 50/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.5172 - sparse_categorical_accuracy: 0.9320 - val_loss: 0.3872 - val_sparse_categorical_accuracy: 0.9703
